# %%
from imu.snowflake import SnowflakeClient, SnowflakeConfig
from ibis import literal
import pyarrow.parquet as pq
import fsspec


import pandas as pd

# %%
# All the snow flake interactions use a package called IBIS, which converts pythonis queries in SQL.  
client = SnowflakeClient()
client
# Out:
# /mnt/custom-file-systems/efs/fs-0fe038ab038fa8cf2_fsap-0c3114cafc9c62295/FCS_File_Quality_Scanner/.venv/lib/python3.12/site-packages/snowflake/connector/options.py:104: UserWarning: You have an incompatible version of 'pyarrow' installed (20.0.0), please install a version that adheres to: 'pyarrow<19.0.0; extra == "pandas"'
#   warn_incompatible_dep(
# SnowflakeClient(connection_info={'user': 'IMU_DAGSTER_PROD_READ_ONLY', 'account': 'RP68682.eu-west-1', 'role': 'IMU_DAGSTER_PROD_READ_ONLY', 'warehouse': 'IMU_WAREHOUSE'})

# %%
## SAMPLE TRACKING SHEET ##
samples_table = client.table('V_FCS_TRACKED_SAMPLES', database='IMU.IMU')
#samples_table.limit(5).execute()

# %%
## Natural Gates created from Manual Analysis ##
natural_manual = client.table('V_WSP_MEMBERSHIPS_LATEST', database='IMU.IMU_DAGSTER_LINEAGE')
#natural_manual.limit(5).execute()

# %%
# Merged together the sample table and manual_natural on the S3 location of the fcs file
natural_manual_metadata = samples_table.join(natural_manual, (literal('s3://') + samples_table['S3 file path']) == natural_manual['FCS_S3_URI'])

# %%
# Create a pandas DataFrame 
natural_manual_metadata = natural_manual_metadata.execute()

# %%
# 'MFI_S3_URI' contains that MFI average for each gate
pd.read_csv(natural_manual_metadata.loc[0,'MFI_S3_URI']).head(3)
# Out:
#   marker  root/LIVE_CELLS_2  root/LIVE_CELLS_2/CD3n  \
# 0   CD16           0.255620                0.280963
# 1  HLADR           0.376278                0.444261
# 2   CD56           0.233045                0.254550
# 3    CD4           0.423496                0.336300
#
#    root/LIVE_CELLS_2/CD3n/B_2  root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27n_2  \
# 0                    0.222221                                 0.228196
# 1                    0.507798                                 0.509768
# 2                    0.201985                                 0.209177
# 3                    0.204136                                 0.198072
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27p_2  \
# 0                                 0.220360
# 1                                 0.499275
# 2                                 0.190180
# 3                                 0.211897
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27n_2  \
# 0                                 0.212004
# 1                                 0.508258
# 2                                 0.193343
# 3                                 0.194596
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27p_2  root/LIVE_CELLS_2/CD3n/B_2/CD10n  \
# 0                                 0.216827                          0.224309
# 1                                 0.504821                          0.507533
# 2                                 0.203065                          0.205969
# 3                                 0.368660                          0.209301
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD10n/NON_PLASMABLAST_2  ...  \
# 0                                           0.224676   ...
# 1                                           0.507554   ...
# 2                                           0.205932   ...
# 3                                           0.209595   ...
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD5p_2  \
# 0                                           0.242245
# 1                                           0.336407
# 2                                           0.223941
# 3                                           0.202042
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD38p_2  \
# 0                                           0.249131
# 1                                           0.341114
# 2                                           0.223906
# 3                                           0.210415
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD62Lp_2  \
# 0                                           0.241772
# 1                                           0.333232
# 2                                           0.223967
# 3                                           0.204644
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD69p_2  \
# 0                                           0.249024
# 1                                           0.357479
# 2                                           0.232558
# 3                                           0.208794
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD319p_2  \
# 0                                           0.248630
# 1                                           0.334506
# 2                                           0.233256
# 3                                           0.195688
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/HLADRp_2  \
# 0                                           0.200862
# 1                                           0.452734
# 2                                           0.252763
# 3                                           0.241740
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PD1p_2  \
# 0                                           0.238122
# 1                                           0.346693
# 2                                           0.222593
# 3                                           0.193563
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PDL1p_2     /root  \
# 0                                           0.246642      0.255620
# 1                                           0.357110      0.376278
# 2                                           0.211236      0.233045
# 3                                           0.309303      0.423496
#
#                                         S3 file path
# 0  s3://imu-flowcytometer-ew1-prod/transcribed-si...
# 1  s3://imu-flowcytometer-ew1-prod/transcribed-si...
# 2  s3://imu-flowcytometer-ew1-prod/transcribed-si...
# 3  s3://imu-flowcytometer-ew1-prod/transcribed-si...
#
# [4 rows x 233 columns]

# %%
# 'STD_S3_URI' contains the Standard Deviation for each gate
pd.read_csv(natural_manual_metadata.loc[0,'STD_S3_URI']).head(3)
# Out:
#   marker  root/LIVE_CELLS_2  root/LIVE_CELLS_2/CD3n  \
# 0   CD16           0.101652                0.129068
# 1  HLADR           0.087667                0.088117
# 2   CD56           0.095476                0.112096
#
#    root/LIVE_CELLS_2/CD3n/B_2  root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27n_2  \
# 0                    0.071941                                 0.073473
# 1                    0.030334                                 0.030959
# 2                    0.074520                                 0.076765
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27p_2  \
# 0                                 0.065777
# 1                                 0.029926
# 2                                 0.068124
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27n_2  \
# 0                                 0.070850
# 1                                 0.028568
# 2                                 0.073286
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27p_2  root/LIVE_CELLS_2/CD3n/B_2/CD10n  \
# 0                                 0.071376                          0.071516
# 1                                 0.031491                          0.030689
# 2                                 0.057174                          0.075089
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD10n/NON_PLASMABLAST_2  ...  \
# 0                                           0.071304   ...
# 1                                           0.030762   ...
# 2                                           0.075365   ...
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD5p_2  \
# 0                                           0.080528
# 1                                           0.049659
# 2                                           0.082372
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD38p_2  \
# 0                                           0.094885
# 1                                           0.048176
# 2                                           0.087000
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD62Lp_2  \
# 0                                           0.079688
# 1                                           0.046066
# 2                                           0.081112
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD69p_2  \
# 0                                           0.065470
# 1                                           0.059540
# 2                                           0.120108
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD319p_2  \
# 0                                           0.075430
# 1                                           0.052377
# 2                                           0.100947
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/HLADRp_2  \
# 0                                           0.065060
# 1                                           0.018466
# 2                                           0.072009
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PD1p_2  \
# 0                                           0.082300
# 1                                           0.053358
# 2                                           0.090700
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PDL1p_2     /root  \
# 0                                           0.067257      0.101652
# 1                                           0.084082      0.087667
# 2                                           0.038967      0.095476
#
#                                         S3 file path
# 0  s3://imu-flowcytometer-ew1-prod/transcribed-si...
# 1  s3://imu-flowcytometer-ew1-prod/transcribed-si...
# 2  s3://imu-flowcytometer-ew1-prod/transcribed-si...
#
# [3 rows x 233 columns]

# %%
# 'COUNTS_S3_URI' contains the counts 
pd.read_csv(natural_manual_metadata.loc[0,'COUNTS_S3_URI'])
# Out:
#    root/LIVE_CELLS_2  root/LIVE_CELLS_2/CD3n  root/LIVE_CELLS_2/CD3n/B_2  \
# 0               8658                    3123                         981
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27n_2  \
# 0                                      543
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27p_2  \
# 0                                      130
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27n_2  \
# 0                                      278
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27p_2  root/LIVE_CELLS_2/CD3n/B_2/CD10n  \
# 0                                       30                               687
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD10n/NON_PLASMABLAST_2  \
# 0                                                676
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD10n/NON_PLASMABLAST_2/CD5n_CD27n_2  ...  \
# 0                                                444                ...
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD5p_2  \
# 0                                                845
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD38p_2  \
# 0                                                296
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD62Lp_2  \
# 0                                                536
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD69p_2  \
# 0                                                 18
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD319p_2  \
# 0                                                 26
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/HLADRp_2  \
# 0                                                 13
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PD1p_2  \
# 0                                                117
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PDL1p_2  /root  \
# 0                                                  4       8658
#
#                                         S3 file path
# 0  s3://imu-flowcytometer-ew1-prod/transcribed-si...
#
# [1 rows x 232 columns]

# %%
# 'EVENTS_S3_URI' contains the individual event MFIs and Memberships 
# Get the S3 path
events_path = natural_manual_metadata.loc[0, "EVENTS_S3_URI"]

# Step 1: Inspect schema with fsspec + pyarrow
with fsspec.open(events_path, "rb") as f:
    parquet_file = pq.ParquetFile(f)
    all_columns = parquet_file.schema.names

# Step 2: Select only columns containing 'root' 
root_columns = [col for col in all_columns if "root" in col.lower()]

# Step 3: Load only those columns into pandas 
df = pd.read_parquet(events_path, columns=root_columns)

df.head()
# Out:
#    root/LIVE_CELLS_2  root/LIVE_CELLS_2/CD3n  root/LIVE_CELLS_2/CD3n/B_2  \
# 0               True                   False                       False
# 1               True                    True                       False
# 2               True                    True                       False
# 3               True                   False                       False
# 4               True                    True                        True
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27n_2  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                     True
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27p_2  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27n_2  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27p_2  root/LIVE_CELLS_2/CD3n/B_2/CD10n  \
# 0                                    False                             False
# 1                                    False                             False
# 2                                    False                             False
# 3                                    False                             False
# 4                                    False                              True
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD10n/NON_PLASMABLAST_2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD10n/NON_PLASMABLAST_2/CD5n_CD27n_2  ...  \
# 0                                              False                ...
# 1                                              False                ...
# 2                                              False                ...
# 3                                              False                ...
# 4                                               True                ...
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD5p_2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD38p_2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD62Lp_2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD69p_2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD319p_2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/HLADRp_2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PD1p_2  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PDL1p_2  /root
# 0                                              False       True
# 1                                              False       True
# 2                                              False       True
# 3                                              False       True
# 4                                              False       True
#
# [5 rows x 231 columns]

# %%
# The 'RATIOS_S3_URI' contains the ratios for each gate 
pd.read_csv(natural_manual_metadata.loc[0,'RATIOS_S3_URI'])
# Out:
#    root/LIVE_CELLS_2  root/LIVE_CELLS_2/CD3n  root/LIVE_CELLS_2/CD3n/B_2  \
# 0                1.0                0.360707                    0.113306
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27n_2  \
# 0                                 0.553517
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5n_CD27p_2  \
# 0                                 0.132518
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27n_2  \
# 0                                 0.283384
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD5p_CD27p_2  root/LIVE_CELLS_2/CD3n/B_2/CD10n  \
# 0                                 0.030581                          0.700306
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD10n/NON_PLASMABLAST_2  \
# 0                                           0.689093
#
#    root/LIVE_CELLS_2/CD3n/B_2/CD10n/NON_PLASMABLAST_2/CD5n_CD27n_2  ...  \
# 0                                           0.656805                ...
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD5p_2  \
# 0                                           0.931643
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD38p_2  \
# 0                                           0.326351
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD62Lp_2  \
# 0                                           0.590959
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD69p_2  \
# 0                                           0.019846
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/CD319p_2  \
# 0                                           0.028666
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/HLADRp_2  \
# 0                                           0.014333
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PD1p_2  \
# 0                                           0.128997
#
#    root/LIVE_CELLS_2/CD3p/TOTAL_T_2/T_2/CD8p_T_2/PDL1p_2  /root  \
# 0                                            0.00441          1
#
#                                         S3 file path
# 0  s3://imu-flowcytometer-ew1-prod/transcribed-si...
#
# [1 rows x 232 columns]

# %%
## Natural Gates created from ML-Predicted Analysis ##
natural_predicted = client.table('V_PREDICTED_MEMBERSHIPS_LATEST',database='IMU.IMU_DAGSTER_LINEAGE')
natural_predicted.limit(5).execute()
# Out:
#                                           FCS_S3_URI  \
# 0  s3://melio-imuuk-shared-prod/sony-data/Other_e...
# 1  s3://melio-imuuk-shared-prod/sony-data/07_Samp...
# 2  s3://melio-imuuk-shared-prod/sony-data/07_Samp...
# 3  s3://melio-imuuk-shared-prod/sony-data/07_Samp...
# 4  s3://imu-flowcytometer-ew1-prod/CW_803022/07_S...
#
#                             FCS_XFORM_PARQUET_S3_URI  \
# 0  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 1  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 2  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 3  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 4  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
#
#                              FCS_XFORM_PARQUE_S3_URI  \
# 0  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 1  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 2  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 3  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 4  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
#
#                                         MODEL_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                        EVENTS_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                        COUNTS_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                        RATIOS_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                           MFI_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                           STD_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                      OUTPUT_MANIFEST  ... PANEL CHANNEL_COUNT  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/lab_...  ...   Tv2           127
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/pair...  ...   Av2           115
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/p1k_...  ...   Av1           115
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/p1k_...  ...   Av1           115
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/exac...  ...   Av4           118
#
#                 MELIO_EXTERNAL_ID                  SAMPLE_ID  SAMPLE_TYPE  \
# 0  IMU025_20240227_FWB_rtON_Tech2        IMU025_20240227_FWB     WB_FRESH
# 1                    0045_BL_PBMC               0045_BL_PBMC  PBMC_FROZEN
# 2                        41023522                       None     WB_FRESH
# 3                        41023803                       None     WB_FRESH
# 4       S0108610_EX004_PB004_PBMC  S0108610_EX004_PB004_PBMC  PBMC_FROZEN
#
#   EXCLUDE_FROM_LINEAGE          ACQUISITION_TS LABGURU_STOCK_ID INSTRUMENT_ID  \
# 0                False 2024-02-29 18:12:26.300            11321        803022
# 1                False 2024-04-25 21:09:00.030            14356        803022
# 2                False 2022-03-15 19:55:09.480             1934        803022
# 3                False 2022-04-06 19:22:13.090             3356        803022
# 4                False 2025-01-16 15:28:19.110            20811        803022
#
#                   ACQUISITION_ID
# 0  2024022918122630_803022_11321
# 1  2024042521090003_803022_14356
# 2   2022031519550948_803022_1934
# 3   2022040619221309_803022_3356
# 4  2025011615281911_803022_20811
#
# [5 rows x 74 columns]

# %%
## Synthetic Gates created from Manual Analysis ##
synthetic_manual = client.table('V_WSP_SYNTHETIC_MEMBERSHIPS_MANUAL_LATEST', database='IMU.IMU_DAGSTER_LINEAGE')
synthetic_manual.limit(5).execute()
# Out:
#                                           FCS_S3_URI  \
# 0  imu-flowcytometer-ew1-prod/CW_803022/07_Sample...
# 1  imu-flowcytometer-ew1-prod/CW_803022/07_Sample...
# 2  imu-flowcytometer-ew1-prod/CW_803022/07_Sample...
# 3  imu-flowcytometer-ew1-prod/CW_803022/07_Sample...
# 4  imu-flowcytometer-ew1-prod/CW_803022/07_Sample...
#
#                                           WSP_S3_URI  \
# 0  s3://imu-prod-ew1-main-wsp-storage/files/029R2...
# 1  s3://imu-prod-ew1-main-wsp-storage/files/02721...
# 2  s3://imu-prod-ew1-main-wsp-storage/files/02721...
# 3  s3://imu-prod-ew1-main-wsp-storage/files/02721...
# 4  s3://imu-prod-ew1-main-wsp-storage/files/029R2...
#
#                                           MFI_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                           STD_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                        COUNTS_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                        RATIOS_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                   MEMBERSHIPS_S3_URI MANIFEST  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...     None
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...     None
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...     None
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...     None
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...     None
#
#     MATERIALIZE_START_AT_UTC     MATERIALIZE_END_AT_UTC  ...  \
# 0 2025-07-24 13:58:42.517780 2025-07-24 14:01:51.113572  ...
# 1 2025-07-24 13:51:14.604555 2025-07-24 13:54:04.571246  ...
# 2 2025-07-24 13:55:44.092228 2025-07-24 14:01:40.935615  ...
# 3 2025-07-24 13:59:19.079644 2025-07-24 14:02:29.354830  ...
# 4 2025-07-24 13:56:57.039866 2025-07-24 14:00:06.601497  ...
#
#                              OUTPUT_NAME  \
# 0  synthetic_population_generation_asset
# 1  synthetic_population_generation_asset
# 2  synthetic_population_generation_asset
# 3  synthetic_population_generation_asset
# 4  synthetic_population_generation_asset
#
#                                  RUN_ID  \
# 0  3aa9a436-ddef-4ea0-b126-7f5569cc8a04
# 1  848ce497-a123-4ff8-8937-bf4d343bff1c
# 2  13f2639c-fce0-4b54-8065-1c2b128f4734
# 3  7b4b5041-74f0-434c-b454-7fa14afbb02f
# 4  54d9f7b8-a3ea-498a-8368-989acfc60f53
#
#                                               INPUTS  \
# 0  {'Tv5_panel_quadrants_simplified.csv': {'creat...
# 1  {'Tv5_panel_quadrants_simplified.csv': {'creat...
# 2  {'Tv5_panel_quadrants_simplified.csv': {'creat...
# 3  {'Tv5_panel_quadrants_simplified.csv': {'creat...
# 4  {'Tv5_panel_quadrants_simplified.csv': {'creat...
#
#                                      INPUTS_CHECKSUM  \
# 0  e1779a10a18a64e2067f86c7aff3d4a10a16d7fdbb5ecc...
# 1  01896c307ea2b642dc39382395236d1e991f8f8d1e6954...
# 2  4fd50e1644a77730bff0691fb1a3f29fa08c5cb79347f6...
# 3  6f37d97be9ee3d306cdfdfa48782a5a50426b42a0562e2...
# 4  dc4cca7bc24ef633b4eb64432fd8e0058d943d7f4b4bc8...
#
#                                              OUTPUTS  \
# 0  {'counts': {'ContentType': 'application/octet-...
# 1  {'counts': {'ContentType': 'application/octet-...
# 2  {'counts': {'ContentType': 'application/octet-...
# 3  {'counts': {'ContentType': 'application/octet-...
# 4  {'counts': {'ContentType': 'application/octet-...
#
#                                                BUILD           BRANCH  \
# 0  {'branch': 'refs/heads/main', 'built_at_utc': ...  refs/heads/main
# 1  {'branch': 'refs/heads/main', 'built_at_utc': ...  refs/heads/main
# 2  {'branch': 'refs/heads/main', 'built_at_utc': ...  refs/heads/main
# 3  {'branch': 'refs/heads/main', 'built_at_utc': ...  refs/heads/main
# 4  {'branch': 'refs/heads/main', 'built_at_utc': ...  refs/heads/main
#
#    RELEASE_VERSION                                     LINEAGE_OBJECT RN
# 0  20250723_130234  {'Partition key': {'fcs_lineage_modified_at': ...  1
# 1  20250723_130234  {'Partition key': {'fcs_lineage_modified_at': ...  1
# 2  20250723_130234  {'Partition key': {'fcs_lineage_modified_at': ...  1
# 3  20250723_130234  {'Partition key': {'fcs_lineage_modified_at': ...  1
# 4  20250723_130234  {'Partition key': {'fcs_lineage_modified_at': ...  1
#
# [5 rows x 23 columns]

# %%
## Synthetic Gates created from ML-Predicted Analysis ##
synthetic_predicted = client.table('V_WSP_SYNTHETIC_MEMBERSHIPS_PREDICTED_LATEST',database='IMU.IMU_DAGSTER_LINEAGE')
synthetic_predicted.limit(5).execute()
# Out:
#                                           FCS_S3_URI  \
# 0  s3://imu-flowcytometer-ew1-prod/CW_803022/07_S...
# 1  s3://imu-flowcytometer-ew1-prod/CW_803022/07_S...
# 2  s3://imu-flowcytometer-ew1-prod/CW_803022/07_S...
# 3  s3://imu-flowcytometer-ew1-prod/CW_803022/07_S...
# 4  s3://imu-flowcytometer-ew1-prod/CW_803022/07_S...
#
#                             FCS_XFORM_PARQUET_S3_URI  \
# 0  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 1  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 2  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 3  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
# 4  s3://melio-imuuk-shared-prod/fcs-parquet_5/202...
#
#                                         MODEL_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                        COUNTS_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                        RATIOS_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                           MFI_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                           STD_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                   MEMBERSHIPS_S3_URI  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/sage...
#
#                                      OUTPUT_MANIFEST  \
# 0  s3://imu-prod-ew1-main-dagster-storage/v2/nmdp...
# 1  s3://imu-prod-ew1-main-dagster-storage/v2/nmdp...
# 2  s3://imu-prod-ew1-main-dagster-storage/v2/nmdp...
# 3  s3://imu-prod-ew1-main-dagster-storage/v2/nmdp...
# 4  s3://imu-prod-ew1-main-dagster-storage/v2/nmdp...
#
#     MATERIALIZE_START_AT_UTC  ... CHANNEL_COUNT   MELIO_EXTERNAL_ID  \
# 0 2025-07-25 14:55:05.995598  ...           133  R220112000217_PBMC
# 1 2025-07-25 14:56:39.051801  ...           133  R220203000195_PBMC
# 2 2025-07-25 14:57:18.611499  ...           133  R220601001234_PBMC
# 3 2025-07-25 14:57:24.625647  ...           133  R220610000249_PBMC
# 4 2025-07-25 14:57:17.814902  ...           133  R220630000349_PBMC
#
#             SAMPLE_ID  SAMPLE_TYPE EXCLUDE_FROM_LINEAGE  \
# 0  R220112000217_PBMC  PBMC_FROZEN                False
# 1  R220203000195_PBMC  PBMC_FROZEN                False
# 2  R220601001234_PBMC  PBMC_FROZEN                False
# 3  R220610000249_PBMC  PBMC_FROZEN                False
# 4  R220630000349_PBMC  PBMC_FROZEN                False
#
#            ACQUISITION_TS LABGURU_STOCK_ID INSTRUMENT_ID  \
# 0 2024-07-01 18:25:14.440            14724        803022
# 1 2024-07-01 18:26:34.170            14732        803022
# 2 2024-07-01 18:27:55.620            14740        803022
# 3 2024-07-01 18:29:18.450            14748        803022
# 4 2024-07-01 18:30:40.950            14756        803022
#
#                   ACQUISITION_ID RN
# 0  2024070118251444_803022_14724  1
# 1  2024070118263417_803022_14732  1
# 2  2024070118275562_803022_14740  1
# 3  2024070118291845_803022_14748  1
# 4  2024070118304095_803022_14756  1
#
# [5 rows x 74 columns]
